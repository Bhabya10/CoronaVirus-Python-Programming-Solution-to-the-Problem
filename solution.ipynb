# %%
import pandas as pd

# %% [markdown]
# # Reading Data

# %%
df=pd.read_csv('data.csv')

# %%
df.head()
# Out:
#         fever  Body Pain   age  runnyNose  difficulty breath  infection prob
# 0  101.237282        0.0  47.0        0.0                1.0             1.0
# 1   99.661903        0.0  28.0        0.0                0.0             0.0
# 2   98.640465        1.0   0.0        1.0               -1.0             1.0
# 3   99.239645        0.0  28.0        0.0                0.0             0.0
# 4  101.076366        1.0  32.0        0.0               -1.0             1.0

# %%
df['difficulty breath'].value_counts()
# Out:
#  0.0    1837
# -1.0     472
#  1.0     459
# Name: difficulty breath, dtype: int64

# %%
df.describe()
# Out:
#              fever    Body Pain          age    runnyNose  difficulty breath  \
# count  2778.000000  2768.000000  2768.000000  2768.000000        2768.000000
# mean    100.015897     0.250000    38.575867     0.254697          -0.004697
# std       1.166268     0.433091    23.238025     0.435769           0.580037
# min      98.000028     0.000000     0.000000     0.000000          -1.000000
# 25%      98.996770     0.000000    28.000000     0.000000           0.000000
# 50%     100.002163     0.000000    28.000000     0.000000           0.000000
# 75%     101.053187     0.250000    49.000000     1.000000           0.000000
# max     101.997625     1.000000   100.000000     1.000000           1.000000
#
#        infection prob
# count     2768.000000
# mean         0.253974
# std          0.435362
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# # Train Test Splitting

# %%
import numpy as np

# %%
def data_split(data,ratio):
    np.random.seed(42)
    shuffled=np.random.permutation(len(data))
    test_set_size=int(len(data)*ratio)
    test_indices=shuffled[:test_set_size]
    train_indices=shuffled[test_set_size:]
    return data.iloc[train_indices],data.iloc[test_indices]

# %%
np.random.permutation(7)
# Out:
# array([4, 0, 1, 2, 6, 5, 3])

# %%
train,test=data_split(df,0.2)

# %%
train
# Out:
#            fever  Body Pain   age  runnyNose  difficulty breath  \
# 315   101.169338        0.0  28.0        0.0                0.0
# 610    98.337130        0.0  86.0        1.0                0.0
# 2451  100.656593        0.0  28.0        0.0                0.0
# 2266  100.957753        0.0  15.0        1.0                0.0
# 2398  101.477909        1.0  30.0        1.0               -1.0
# ...          ...        ...   ...        ...                ...
# 1638   99.926307        0.0  71.0        0.0               -1.0
# 1095  100.977505        0.0  28.0        0.0                0.0
# 1130   99.167471        0.0  88.0        0.0               -1.0
# 1294  100.554546        0.0  56.0        1.0                0.0
# 860   100.032554        0.0  30.0        0.0                0.0
#
#       infection prob
# 315              0.0
# 610              0.0
# 2451             0.0
# 2266             0.0
# 2398             0.0
# ...              ...
# 1638             1.0
# 1095             0.0
# 1130             1.0
# 1294             1.0
# 860              1.0
#
# [2223 rows x 6 columns]

# %%
test
# Out:
#            fever  Body Pain   age  runnyNose  difficulty breath  \
# 879   100.213708        0.0  28.0        0.0                0.0
# 1990   99.565413        1.0  58.0        0.0                1.0
# 889   101.289094        0.0  28.0        0.0                0.0
# 912    98.407762        0.0  61.0        0.0               -1.0
# 2633  101.509863        0.0  28.0        0.0                0.0
# ...          ...        ...   ...        ...                ...
# 238   100.925361        1.0  38.0        0.0               -1.0
# 1980   98.156029        0.0  61.0        1.0                1.0
# 1950   99.641789        1.0  21.0        0.0               -1.0
# 1702   99.203829        1.0  85.0        1.0                1.0
# 100    98.266676        1.0  18.0        1.0                0.0
#
#       infection prob
# 879              0.0
# 1990             0.0
# 889              0.0
# 912              1.0
# 2633             0.0
# ...              ...
# 238              1.0
# 1980             0.0
# 1950             0.0
# 1702             1.0
# 100              1.0
#
# [555 rows x 6 columns]

# %%
X_train = train[['fever','Body Pain','age','runnyNose','difficulty breath']].to_numpy()
X_test = test[['fever','Body Pain','age','runnyNose','difficulty breath']].to_numpy()

# %%
Y_train = train[['infection prob']].to_numpy().reshape(2225 ,)
Y_test = test[['infection prob']].to_numpy().reshape(556 ,)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_848/3512275099.py in <module>
# ----> 1 Y_train = train[['infection prob']].to_numpy().reshape(2225 ,)
#       2 Y_test = test[['infection prob']].to_numpy().reshape(556 ,)
#
# ValueError: cannot reshape array of size 2223 into shape (2225,)

# %%
Y_train
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()
clf.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_848/2206203607.py in <module>
#       1 clf=LogisticRegression()
# ----> 2 clf.fit(X_train, Y_train)
#       3
#
# c:\python3.9\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1342             _dtype = [np.float64, np.float32]
#    1343
# -> 1344         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
#
# c:\python3.9\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# c:\python3.9\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\python3.9\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     869         raise ValueError("y cannot be None")
#     870
# --> 871     X = check_array(X, accept_sparse=accept_sparse,
#     872                     accept_large_sparse=accept_large_sparse,
#     873                     dtype=dtype, order=order, copy=copy,
#
# c:\python3.9\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\python3.9\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     718
#     719         if force_all_finite:
# --> 720             _assert_all_finite(array,
#     721                                allow_nan=force_all_finite == 'allow-nan')
#     722
#
# c:\python3.9\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101                 not allow_nan and not np.isfinite(X).all()):
#     102             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# --> 103             raise ValueError(
#     104                     msg_err.format
#     105                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
